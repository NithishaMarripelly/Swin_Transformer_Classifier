# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

import torch
import torch.nn as nn 
import torch.optim as optim
import torch.nn.functional as F 
import torch.backends.cudnn as cudnn 
import numpy as np
import sys

import torchvision
import torchvision.transforms as transforms

import matplotlib.pyplot as plt
import os 
import argparse
import pandas as pd 
import csv
import time
from randomaug import RandAugment 
from swin_transformer_pytorch import swin_t
import Utils

# %% [markdown]
# ### Set Training Configuration: Device, Model, and Hyperparameters via ArgParser

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu' # parsers
parser = argparse.ArgumentParser(description='PyTorch CIFAR10 Training') 
parser.add_argument('--dataset', default='CIFAR10') # options: CIFAR10, CIFAR100 
parser.add_argument('--dataset_classes', default='10') # options: 10 for CIFAR10, 100 fr CIFAR100
parser.add_argument('--lr', default=1e-4, type=float, help='learning rate') # 
parser.add_argument('--opt', default="adam")
parser.add_argument('--resume', '-r', action='store_true', help='resume from checkpoint')
parser.add_argument('--noaug', action='store_false', help='disable use randomaug') 
parser.add_argument('--noamp', action='store_true', help='disable mixed precision training. for older pytorch versions')
parser.add_argument('--net', default='swin') # options: vit, swin, cait, twins
parser.add_argument('--heads', default='6') 
parser.add_argument('--layers', default='12')    # depth
parser.add_argument('--dp', action='store_true', help='use data parallel') 
parser.add_argument('--bs', default='64')    # was 512
parser.add_argument('--size', default="32") 
parser.add_argument('--n_epochs', type=int, default='100')
parser.add_argument('--patch', default='4', type=int, help="patch for ViT") 
parser.add_argument('--dimhead', default="420", type=int) # or 512

args = parser.parse_args(args=[
    '--dataset', 'CIFAR10',
    '--dataset_classes', '10',
    '--lr', '0.0001',
    '--opt', 'adam',
    '--net', 'swin',
    '--heads', '6',
    '--layers', '12',
    '--bs', '200',
    '--size', '32',
    '--n_epochs', '200',
    '--patch', '4',
    '--dimhead', '420',
    '--noaug',
    '--noamp',
    '--dp'
])

best_acc = 0

# %% [markdown]
# ### Count number of trainable parameters in the model

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# ### Defining the main training pipeline

# %%
def main():
    bs = int(args.bs) 
    imsize = int(args.size)
    
    use_amp = not args.noamp 
    aug = args.noaug
    global net, testloader
    best_acc = 0    # best test accuracy
    start_epoch = 0    # start from epoch 0 or last checkpoint epoch
    
    # Data
    print('==> Preparing data..') 
    size = imsize
    trainloader, testloader = Utils.get_loaders_CIFAR10(size, bs) 
    
    classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
    
    # Model factory..
    net = swin_t(window_size=int(args.patch),
                 num_classes=int(args.dataset_classes), downscaling_factors=(2,2,2,1)).to(device)
    pcount = count_parameters(net)
    print("count of parameters in the model = ", pcount/1e6, " million") 
    
    if args.resume:
        # Load checkpoint.
        print('==> Resuming from checkpoint..')
        assert os.path.isdir('checkpoint'), 'Error: no checkpoint directory found!' 
        checkpoint = torch.load('./checkpoint/{}-ckpt.t7'.format(args.net)) 
        net.load_state_dict(checkpoint['model'])
        best_acc = checkpoint['acc'] 
        start_epoch = checkpoint['epoch']
    
    # Loss is CE
    criterion = nn.CrossEntropyLoss()
    
    if args.opt == "adam":
        optimizer = optim.Adam(net.parameters(), lr=args.lr) 
    elif args.opt == "sgd":
        optimizer = optim.SGD(net.parameters(), lr=args.lr)
    
    # use cosine scheduling
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, args.n_epochs)
    
    ##### Training
    scaler = torch.cuda.amp.GradScaler(enabled=use_amp) 
    list_loss = []
    list_acc = []
    list_train_acc = []
    list_train_loss = []
    
    
    net.cuda()
    for epoch in range(start_epoch, args.n_epochs): 
        start = time.time()
        train_loss, train_acc = train(epoch, net, trainloader, criterion,scaler,optimizer, use_amp)
     
    
        val_loss, val_acc = test(epoch, net, testloader, criterion, optimizer, scaler) 
        print(f"Epoch {epoch+1}/{args.n_epochs} | Val Loss: {val_loss:.4f} | Val Accuracy: {val_acc:.2f}%")
        scheduler.step() # step cosine scheduling list_loss.append(val_loss)
        list_train_loss.append(train_loss)
        list_train_acc.append(train_acc)
        list_loss.append(val_loss)
        list_acc.append(val_acc)

    return testloader, list_loss, list_acc, list_train_loss, list_train_acc

# %% [markdown]
# ### Training Function

# %%
def train(epoch, net, trainloader, criterion, scaler, optimizer, use_amp): 
    print('\nEpoch: %d' % (epoch+1))
    net.train() 
    train_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(trainloader): 
        inputs, targets = inputs.to(device), targets.to(device) # Train with amp
        with torch.cuda.amp.autocast(enabled=use_amp): 
            outputs = net(inputs)
            loss = criterion(outputs, targets) 
        scaler.scale(loss).backward() 
        scaler.step(optimizer)
        scaler.update() 
        optimizer.zero_grad()
    
        train_loss += loss.item()
        _, predicted = outputs.max(1) 
        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()
     
    
    print(batch_idx, len(trainloader), 'TrainLoss: %.3f | TrainAcc: %.3f%% (%d/%d)'
          % (train_loss/(batch_idx+1), 100.*correct/total, correct, total)) 
    return train_loss/(batch_idx+1), 100.*correct/total

# %% [markdown]
# ### Testing Function

# %%
def test(epoch, net, testloader, criterion, optimizer, scaler): 
    global best_acc
    net.eval() 
    test_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(testloader): 
            inputs, targets = inputs.to(device), targets.to(device) 
            outputs = net(inputs)
            loss = criterion(outputs, targets) 
            test_loss += loss.item()
            _, predicted = outputs.max(1) 
            total += targets.size(0)
            correct += predicted.eq(targets).sum().item()
    
        print(batch_idx, len(testloader), 'ValLoss: %.3f | Val Acc: %.3f%% (%d/%d)' 
              % (test_loss/(batch_idx+1), 100.*correct/total, correct, total))

    # Save checkpoint.
    acc = 100.*correct/total 
    if acc > best_acc:
        print('Saving..')
        state = {"model": net.state_dict(), 
                 "optimizer": optimizer.state_dict(), 
                 "acc": acc, "epoch": epoch, 
                 "scaler": scaler.state_dict()} 
        if not os.path.isdir('checkpoint'):
            os.mkdir('checkpoint')
        torch.save(state, './checkpoint/'+args.net+'-{}-ckpt.t7'.format(args.patch)) 
        best_acc = acc
    return test_loss/(batch_idx+1), acc

# %% [markdown]
# ### Run Main Function to Train Model and Collect Metrics

# %%
testloader, list_loss, list_acc, list_train_loss, list_train_acc  = main()
# Out:
# ==> Preparing data..
# Files already downloaded and verified
# Files already downloaded and verified
# count of parameters in the model =  26.598646  million
#
# Epoch: 1
# 249 250 TrainLoss: 2.276 | TrainAcc: 14.108% (7054/50000)
# 99 100 ValLoss: 2.011 | Val Acc: 24.830% (2483/10000)
# Saving..
# Epoch 1/200 | Val Loss: 2.0113 | Val Accuracy: 24.83%
#
# Epoch: 2
# 249 250 TrainLoss: 2.118 | TrainAcc: 20.026% (10013/50000)
# 99 100 ValLoss: 1.797 | Val Acc: 32.600% (3260/10000)
# Saving..
# Epoch 2/200 | Val Loss: 1.7968 | Val Accuracy: 32.60%
#
# Epoch: 3
# 249 250 TrainLoss: 1.999 | TrainAcc: 24.864% (12432/50000)
# 99 100 ValLoss: 1.595 | Val Acc: 41.020% (4102/10000)
# Saving..
# Epoch 3/200 | Val Loss: 1.5951 | Val Accuracy: 41.02%
#
# Epoch: 4
# 249 250 TrainLoss: 1.930 | TrainAcc: 27.654% (13827/50000)
# 99 100 ValLoss: 1.544 | Val Acc: 41.630% (4163/10000)
# Saving..
# Epoch 4/200 | Val Loss: 1.5443 | Val Accuracy: 41.63%
#
# Epoch: 5
# 249 250 TrainLoss: 1.865 | TrainAcc: 30.486% (15243/50000)
# 99 100 ValLoss: 1.439 | Val Acc: 47.560% (4756/10000)
# Saving..
# Epoch 5/200 | Val Loss: 1.4388 | Val Accuracy: 47.56%
#
# Epoch: 6
# 249 250 TrainLoss: 1.820 | TrainAcc: 31.978% (15989/50000)
# 99 100 ValLoss: 1.351 | Val Acc: 50.790% (5079/10000)
# Saving..
# Epoch 6/200 | Val Loss: 1.3513 | Val Accuracy: 50.79%
#
# Epoch: 7
# 249 250 TrainLoss: 1.782 | TrainAcc: 33.948% (16974/50000)
# 99 100 ValLoss: 1.347 | Val Acc: 50.440% (5044/10000)
# Epoch 7/200 | Val Loss: 1.3474 | Val Accuracy: 50.44%
#
# Epoch: 8
# 249 250 TrainLoss: 1.742 | TrainAcc: 35.224% (17612/50000)
# 99 100 ValLoss: 1.268 | Val Acc: 53.780% (5378/10000)
# Saving..
# Epoch 8/200 | Val Loss: 1.2676 | Val Accuracy: 53.78%
#
# Epoch: 9
# 249 250 TrainLoss: 1.721 | TrainAcc: 36.226% (18113/50000)
# 99 100 ValLoss: 1.202 | Val Acc: 56.330% (5633/10000)
# Saving..
# Epoch 9/200 | Val Loss: 1.2018 | Val Accuracy: 56.33%
#
# Epoch: 10
# 249 250 TrainLoss: 1.687 | TrainAcc: 37.522% (18761/50000)
# 99 100 ValLoss: 1.193 | Val Acc: 56.940% (5694/10000)
# Saving..
# Epoch 10/200 | Val Loss: 1.1934 | Val Accuracy: 56.94%
#
# Epoch: 11
# 249 250 TrainLoss: 1.671 | TrainAcc: 37.886% (18943/50000)
# 99 100 ValLoss: 1.158 | Val Acc: 57.910% (5791/10000)
# Saving..
# Epoch 11/200 | Val Loss: 1.1582 | Val Accuracy: 57.91%
#
# Epoch: 12
# 249 250 TrainLoss: 1.648 | TrainAcc: 38.744% (19372/50000)
# 99 100 ValLoss: 1.110 | Val Acc: 59.850% (5985/10000)
# Saving..
# Epoch 12/200 | Val Loss: 1.1099 | Val Accuracy: 59.85%
#
# Epoch: 13
# 249 250 TrainLoss: 1.616 | TrainAcc: 40.184% (20092/50000)
# 99 100 ValLoss: 1.111 | Val Acc: 60.600% (6060/10000)
# Saving..
# Epoch 13/200 | Val Loss: 1.1112 | Val Accuracy: 60.60%
#
# Epoch: 14
# 249 250 TrainLoss: 1.600 | TrainAcc: 40.638% (20319/50000)
# 99 100 ValLoss: 1.040 | Val Acc: 63.240% (6324/10000)
# Saving..
# Epoch 14/200 | Val Loss: 1.0397 | Val Accuracy: 63.24%
#
# Epoch: 15
# 249 250 TrainLoss: 1.585 | TrainAcc: 41.344% (20672/50000)
# 99 100 ValLoss: 1.047 | Val Acc: 62.020% (6202/10000)
# Epoch 15/200 | Val Loss: 1.0468 | Val Accuracy: 62.02%
#
# Epoch: 16
# 249 250 TrainLoss: 1.564 | TrainAcc: 42.112% (21056/50000)
# 99 100 ValLoss: 1.042 | Val Acc: 62.600% (6260/10000)
# Epoch 16/200 | Val Loss: 1.0415 | Val Accuracy: 62.60%
#
# Epoch: 17
# 249 250 TrainLoss: 1.542 | TrainAcc: 43.114% (21557/50000)
# 99 100 ValLoss: 1.001 | Val Acc: 64.590% (6459/10000)
# Saving..
# Epoch 17/200 | Val Loss: 1.0007 | Val Accuracy: 64.59%
#
# Epoch: 18
# 249 250 TrainLoss: 1.528 | TrainAcc: 43.626% (21813/50000)
# 99 100 ValLoss: 0.992 | Val Acc: 65.170% (6517/10000)
# Saving..
# Epoch 18/200 | Val Loss: 0.9921 | Val Accuracy: 65.17%
#
# Epoch: 19
# 249 250 TrainLoss: 1.519 | TrainAcc: 43.722% (21861/50000)
# 99 100 ValLoss: 0.985 | Val Acc: 65.070% (6507/10000)
# Epoch 19/200 | Val Loss: 0.9847 | Val Accuracy: 65.07%
#
# Epoch: 20
# 249 250 TrainLoss: 1.496 | TrainAcc: 44.806% (22403/50000)
# 99 100 ValLoss: 0.942 | Val Acc: 66.720% (6672/10000)
# Saving..
# Epoch 20/200 | Val Loss: 0.9425 | Val Accuracy: 66.72%
#
# Epoch: 21
# 249 250 TrainLoss: 1.490 | TrainAcc: 44.874% (22437/50000)
# 99 100 ValLoss: 0.929 | Val Acc: 67.550% (6755/10000)
# Saving..
# Epoch 21/200 | Val Loss: 0.9285 | Val Accuracy: 67.55%
#
# Epoch: 22
# 249 250 TrainLoss: 1.481 | TrainAcc: 45.344% (22672/50000)
# 99 100 ValLoss: 0.913 | Val Acc: 68.300% (6830/10000)
# Saving..
# Epoch 22/200 | Val Loss: 0.9125 | Val Accuracy: 68.30%
#
# Epoch: 23
# 249 250 TrainLoss: 1.467 | TrainAcc: 45.916% (22958/50000)
# 99 100 ValLoss: 0.919 | Val Acc: 67.530% (6753/10000)
# Epoch 23/200 | Val Loss: 0.9189 | Val Accuracy: 67.53%
#
# Epoch: 24
# 249 250 TrainLoss: 1.451 | TrainAcc: 46.300% (23150/50000)
# 99 100 ValLoss: 0.881 | Val Acc: 68.870% (6887/10000)
# Saving..
# Epoch 24/200 | Val Loss: 0.8812 | Val Accuracy: 68.87%
#
# Epoch: 25
# 249 250 TrainLoss: 1.443 | TrainAcc: 46.922% (23461/50000)
# 99 100 ValLoss: 0.903 | Val Acc: 68.280% (6828/10000)
# Epoch 25/200 | Val Loss: 0.9034 | Val Accuracy: 68.28%
#
# Epoch: 26
# 249 250 TrainLoss: 1.432 | TrainAcc: 47.248% (23624/50000)
# 99 100 ValLoss: 0.865 | Val Acc: 69.290% (6929/10000)
# Saving..
# Epoch 26/200 | Val Loss: 0.8651 | Val Accuracy: 69.29%
#
# Epoch: 27
# 249 250 TrainLoss: 1.411 | TrainAcc: 47.894% (23947/50000)
# 99 100 ValLoss: 0.851 | Val Acc: 69.940% (6994/10000)
# Saving..
# Epoch 27/200 | Val Loss: 0.8509 | Val Accuracy: 69.94%
#
# Epoch: 28
# 249 250 TrainLoss: 1.410 | TrainAcc: 48.084% (24042/50000)
# 99 100 ValLoss: 0.834 | Val Acc: 70.040% (7004/10000)
# Saving..
# Epoch 28/200 | Val Loss: 0.8339 | Val Accuracy: 70.04%
#
# Epoch: 29
# 249 250 TrainLoss: 1.406 | TrainAcc: 48.160% (24080/50000)
# 99 100 ValLoss: 0.840 | Val Acc: 70.010% (7001/10000)
# Epoch 29/200 | Val Loss: 0.8399 | Val Accuracy: 70.01%
#
# Epoch: 30
# 249 250 TrainLoss: 1.401 | TrainAcc: 48.344% (24172/50000)
# 99 100 ValLoss: 0.826 | Val Acc: 71.020% (7102/10000)
# Saving..
# Epoch 30/200 | Val Loss: 0.8255 | Val Accuracy: 71.02%
#
# Epoch: 31
# 249 250 TrainLoss: 1.389 | TrainAcc: 48.818% (24409/50000)
# 99 100 ValLoss: 0.801 | Val Acc: 72.010% (7201/10000)
# Saving..
# Epoch 31/200 | Val Loss: 0.8008 | Val Accuracy: 72.01%
#
# Epoch: 32
# 249 250 TrainLoss: 1.381 | TrainAcc: 49.010% (24505/50000)
# 99 100 ValLoss: 0.795 | Val Acc: 72.440% (7244/10000)
# Saving..
# Epoch 32/200 | Val Loss: 0.7947 | Val Accuracy: 72.44%
#
# Epoch: 33
# 249 250 TrainLoss: 1.369 | TrainAcc: 49.336% (24668/50000)
# 99 100 ValLoss: 0.807 | Val Acc: 71.570% (7157/10000)
# Epoch 33/200 | Val Loss: 0.8073 | Val Accuracy: 71.57%
#
# Epoch: 34
# 249 250 TrainLoss: 1.359 | TrainAcc: 49.914% (24957/50000)
# 99 100 ValLoss: 0.788 | Val Acc: 72.530% (7253/10000)
# Saving..
# Epoch 34/200 | Val Loss: 0.7879 | Val Accuracy: 72.53%
#
# Epoch: 35
# 249 250 TrainLoss: 1.350 | TrainAcc: 50.198% (25099/50000)
# 99 100 ValLoss: 0.757 | Val Acc: 73.430% (7343/10000)
# Saving..
# Epoch 35/200 | Val Loss: 0.7565 | Val Accuracy: 73.43%
#
# Epoch: 36
# 249 250 TrainLoss: 1.352 | TrainAcc: 50.090% (25045/50000)
# 99 100 ValLoss: 0.756 | Val Acc: 73.480% (7348/10000)
# Saving..
# Epoch 36/200 | Val Loss: 0.7560 | Val Accuracy: 73.48%
#
# Epoch: 37
# 249 250 TrainLoss: 1.336 | TrainAcc: 50.624% (25312/50000)
# 99 100 ValLoss: 0.783 | Val Acc: 72.390% (7239/10000)
# Epoch 37/200 | Val Loss: 0.7831 | Val Accuracy: 72.39%
#
# Epoch: 38
# 249 250 TrainLoss: 1.332 | TrainAcc: 51.116% (25558/50000)
# 99 100 ValLoss: 0.735 | Val Acc: 73.830% (7383/10000)
# Saving..
# Epoch 38/200 | Val Loss: 0.7355 | Val Accuracy: 73.83%
#
# Epoch: 39
# 249 250 TrainLoss: 1.318 | TrainAcc: 51.546% (25773/50000)
# 99 100 ValLoss: 0.719 | Val Acc: 74.680% (7468/10000)
# Saving..
# Epoch 39/200 | Val Loss: 0.7188 | Val Accuracy: 74.68%
#
# Epoch: 40
# 249 250 TrainLoss: 1.309 | TrainAcc: 51.724% (25862/50000)
# 99 100 ValLoss: 0.741 | Val Acc: 73.870% (7387/10000)
# Epoch 40/200 | Val Loss: 0.7413 | Val Accuracy: 73.87%
#
# Epoch: 41
# 249 250 TrainLoss: 1.312 | TrainAcc: 51.612% (25806/50000)
# 99 100 ValLoss: 0.705 | Val Acc: 75.180% (7518/10000)
# Saving..
# Epoch 41/200 | Val Loss: 0.7051 | Val Accuracy: 75.18%
#
# Epoch: 42
# 249 250 TrainLoss: 1.309 | TrainAcc: 51.776% (25888/50000)
# 99 100 ValLoss: 0.698 | Val Acc: 75.320% (7532/10000)
# Saving..
# Epoch 42/200 | Val Loss: 0.6978 | Val Accuracy: 75.32%
#
# Epoch: 43
# 249 250 TrainLoss: 1.287 | TrainAcc: 52.530% (26265/50000)
# 99 100 ValLoss: 0.698 | Val Acc: 74.750% (7475/10000)
# Epoch 43/200 | Val Loss: 0.6977 | Val Accuracy: 74.75%
#
# Epoch: 44
# 249 250 TrainLoss: 1.294 | TrainAcc: 52.236% (26118/50000)
# 99 100 ValLoss: 0.697 | Val Acc: 75.320% (7532/10000)
# Epoch 44/200 | Val Loss: 0.6973 | Val Accuracy: 75.32%
#
# Epoch: 45
# 249 250 TrainLoss: 1.282 | TrainAcc: 52.642% (26321/50000)
# 99 100 ValLoss: 0.675 | Val Acc: 76.050% (7605/10000)
# Saving..
# Epoch 45/200 | Val Loss: 0.6747 | Val Accuracy: 76.05%
#
# Epoch: 46
# 249 250 TrainLoss: 1.279 | TrainAcc: 52.818% (26409/50000)
# 99 100 ValLoss: 0.669 | Val Acc: 76.600% (7660/10000)
# Saving..
# Epoch 46/200 | Val Loss: 0.6689 | Val Accuracy: 76.60%
#
# Epoch: 47
# 249 250 TrainLoss: 1.269 | TrainAcc: 53.160% (26580/50000)
# 99 100 ValLoss: 0.665 | Val Acc: 76.710% (7671/10000)
# Saving..
# Epoch 47/200 | Val Loss: 0.6654 | Val Accuracy: 76.71%
#
# Epoch: 48
# 249 250 TrainLoss: 1.259 | TrainAcc: 53.676% (26838/50000)
# 99 100 ValLoss: 0.657 | Val Acc: 76.650% (7665/10000)
# Epoch 48/200 | Val Loss: 0.6567 | Val Accuracy: 76.65%
#
# Epoch: 49
# 249 250 TrainLoss: 1.257 | TrainAcc: 53.604% (26802/50000)
# 99 100 ValLoss: 0.651 | Val Acc: 77.370% (7737/10000)
# Saving..
# Epoch 49/200 | Val Loss: 0.6511 | Val Accuracy: 77.37%
#
# Epoch: 50
# 249 250 TrainLoss: 1.257 | TrainAcc: 53.392% (26696/50000)
# 99 100 ValLoss: 0.632 | Val Acc: 77.820% (7782/10000)
# Saving..
# Epoch 50/200 | Val Loss: 0.6320 | Val Accuracy: 77.82%
#
# Epoch: 51
# 249 250 TrainLoss: 1.250 | TrainAcc: 53.676% (26838/50000)
# 99 100 ValLoss: 0.633 | Val Acc: 77.830% (7783/10000)
# Saving..
# Epoch 51/200 | Val Loss: 0.6327 | Val Accuracy: 77.83%
#
# Epoch: 52
# 249 250 TrainLoss: 1.245 | TrainAcc: 54.002% (27001/50000)
# 99 100 ValLoss: 0.643 | Val Acc: 77.350% (7735/10000)
# Epoch 52/200 | Val Loss: 0.6427 | Val Accuracy: 77.35%
#
# Epoch: 53
# 249 250 TrainLoss: 1.238 | TrainAcc: 54.186% (27093/50000)
# 99 100 ValLoss: 0.636 | Val Acc: 77.950% (7795/10000)
# Saving..
# Epoch 53/200 | Val Loss: 0.6362 | Val Accuracy: 77.95%
#
# Epoch: 54
# 249 250 TrainLoss: 1.232 | TrainAcc: 54.544% (27272/50000)
# 99 100 ValLoss: 0.621 | Val Acc: 77.960% (7796/10000)
# Saving..
# Epoch 54/200 | Val Loss: 0.6208 | Val Accuracy: 77.96%
#
# Epoch: 55
# 249 250 TrainLoss: 1.231 | TrainAcc: 54.650% (27325/50000)
# 99 100 ValLoss: 0.622 | Val Acc: 78.250% (7825/10000)
# Saving..
# Epoch 55/200 | Val Loss: 0.6215 | Val Accuracy: 78.25%
#
# Epoch: 56
# 249 250 TrainLoss: 1.225 | TrainAcc: 54.588% (27294/50000)
# 99 100 ValLoss: 0.608 | Val Acc: 78.620% (7862/10000)
# Saving..
# Epoch 56/200 | Val Loss: 0.6082 | Val Accuracy: 78.62%
#
# Epoch: 57
# 249 250 TrainLoss: 1.213 | TrainAcc: 55.052% (27526/50000)
# 99 100 ValLoss: 0.622 | Val Acc: 78.210% (7821/10000)
# Epoch 57/200 | Val Loss: 0.6222 | Val Accuracy: 78.21%
#
# Epoch: 58
# 249 250 TrainLoss: 1.219 | TrainAcc: 54.946% (27473/50000)
# 99 100 ValLoss: 0.619 | Val Acc: 78.240% (7824/10000)
# Epoch 58/200 | Val Loss: 0.6187 | Val Accuracy: 78.24%
#
# Epoch: 59
# 249 250 TrainLoss: 1.200 | TrainAcc: 55.636% (27818/50000)
# 99 100 ValLoss: 0.590 | Val Acc: 79.280% (7928/10000)
# Saving..
# Epoch 59/200 | Val Loss: 0.5901 | Val Accuracy: 79.28%
#
# Epoch: 60
# 249 250 TrainLoss: 1.196 | TrainAcc: 55.864% (27932/50000)
# 99 100 ValLoss: 0.587 | Val Acc: 79.530% (7953/10000)
# Saving..
# Epoch 60/200 | Val Loss: 0.5866 | Val Accuracy: 79.53%
#
# Epoch: 61
# 249 250 TrainLoss: 1.199 | TrainAcc: 55.554% (27777/50000)
# 99 100 ValLoss: 0.597 | Val Acc: 79.400% (7940/10000)
# Epoch 61/200 | Val Loss: 0.5966 | Val Accuracy: 79.40%
#
# Epoch: 62
# 249 250 TrainLoss: 1.189 | TrainAcc: 56.282% (28141/50000)
# 99 100 ValLoss: 0.576 | Val Acc: 80.170% (8017/10000)
# Saving..
# Epoch 62/200 | Val Loss: 0.5761 | Val Accuracy: 80.17%
#
# Epoch: 63
# 249 250 TrainLoss: 1.191 | TrainAcc: 55.964% (27982/50000)
# 99 100 ValLoss: 0.589 | Val Acc: 79.450% (7945/10000)
# Epoch 63/200 | Val Loss: 0.5885 | Val Accuracy: 79.45%
#
# Epoch: 64
# 249 250 TrainLoss: 1.184 | TrainAcc: 56.114% (28057/50000)
# 99 100 ValLoss: 0.585 | Val Acc: 79.580% (7958/10000)
# Epoch 64/200 | Val Loss: 0.5854 | Val Accuracy: 79.58%
#
# Epoch: 65
# 249 250 TrainLoss: 1.181 | TrainAcc: 56.136% (28068/50000)
# 99 100 ValLoss: 0.601 | Val Acc: 79.180% (7918/10000)
# Epoch 65/200 | Val Loss: 0.6011 | Val Accuracy: 79.18%
#
# Epoch: 66
# 249 250 TrainLoss: 1.172 | TrainAcc: 56.616% (28308/50000)
# 99 100 ValLoss: 0.562 | Val Acc: 80.560% (8056/10000)
# Saving..
# Epoch 66/200 | Val Loss: 0.5618 | Val Accuracy: 80.56%
#
# Epoch: 67
# 249 250 TrainLoss: 1.164 | TrainAcc: 57.030% (28515/50000)
# 99 100 ValLoss: 0.577 | Val Acc: 79.930% (7993/10000)
# Epoch 67/200 | Val Loss: 0.5772 | Val Accuracy: 79.93%
#
# Epoch: 68
# 249 250 TrainLoss: 1.155 | TrainAcc: 57.052% (28526/50000)
# 99 100 ValLoss: 0.562 | Val Acc: 80.910% (8091/10000)
# Saving..
# Epoch 68/200 | Val Loss: 0.5622 | Val Accuracy: 80.91%
#
# Epoch: 69
# 249 250 TrainLoss: 1.167 | TrainAcc: 56.664% (28332/50000)
# 99 100 ValLoss: 0.559 | Val Acc: 80.460% (8046/10000)
# Epoch 69/200 | Val Loss: 0.5588 | Val Accuracy: 80.46%
#
# Epoch: 70
# 249 250 TrainLoss: 1.155 | TrainAcc: 57.246% (28623/50000)
# 99 100 ValLoss: 0.549 | Val Acc: 81.210% (8121/10000)
# Saving..
# Epoch 70/200 | Val Loss: 0.5492 | Val Accuracy: 81.21%
#
# Epoch: 71
# 249 250 TrainLoss: 1.152 | TrainAcc: 57.228% (28614/50000)
# 99 100 ValLoss: 0.536 | Val Acc: 81.550% (8155/10000)
# Saving..
# Epoch 71/200 | Val Loss: 0.5360 | Val Accuracy: 81.55%
#
# Epoch: 72
# 249 250 TrainLoss: 1.152 | TrainAcc: 57.614% (28807/50000)
# 99 100 ValLoss: 0.554 | Val Acc: 80.720% (8072/10000)
# Epoch 72/200 | Val Loss: 0.5535 | Val Accuracy: 80.72%
#
# Epoch: 73
# 249 250 TrainLoss: 1.144 | TrainAcc: 57.722% (28861/50000)
# 99 100 ValLoss: 0.538 | Val Acc: 81.180% (8118/10000)
# Epoch 73/200 | Val Loss: 0.5377 | Val Accuracy: 81.18%
#
# Epoch: 74
# 249 250 TrainLoss: 1.143 | TrainAcc: 57.452% (28726/50000)
# 99 100 ValLoss: 0.526 | Val Acc: 82.200% (8220/10000)
# Saving..
# Epoch 74/200 | Val Loss: 0.5259 | Val Accuracy: 82.20%
#
# Epoch: 75
# 249 250 TrainLoss: 1.138 | TrainAcc: 57.802% (28901/50000)
# 99 100 ValLoss: 0.515 | Val Acc: 82.230% (8223/10000)
# Saving..
# Epoch 75/200 | Val Loss: 0.5150 | Val Accuracy: 82.23%
#
# Epoch: 76
# 249 250 TrainLoss: 1.127 | TrainAcc: 58.344% (29172/50000)
# 99 100 ValLoss: 0.521 | Val Acc: 81.870% (8187/10000)
# Epoch 76/200 | Val Loss: 0.5210 | Val Accuracy: 81.87%
#
# Epoch: 77
# 249 250 TrainLoss: 1.130 | TrainAcc: 58.034% (29017/50000)
# 99 100 ValLoss: 0.524 | Val Acc: 82.220% (8222/10000)
# Epoch 77/200 | Val Loss: 0.5241 | Val Accuracy: 82.22%
#
# Epoch: 78
# 249 250 TrainLoss: 1.123 | TrainAcc: 58.600% (29300/50000)
# 99 100 ValLoss: 0.529 | Val Acc: 81.570% (8157/10000)
# Epoch 78/200 | Val Loss: 0.5295 | Val Accuracy: 81.57%
#
# Epoch: 79
# 249 250 TrainLoss: 1.121 | TrainAcc: 58.440% (29220/50000)
# 99 100 ValLoss: 0.518 | Val Acc: 82.620% (8262/10000)
# Saving..
# Epoch 79/200 | Val Loss: 0.5184 | Val Accuracy: 82.62%
#
# Epoch: 80
# 249 250 TrainLoss: 1.117 | TrainAcc: 58.578% (29289/50000)
# 99 100 ValLoss: 0.509 | Val Acc: 82.490% (8249/10000)
# Epoch 80/200 | Val Loss: 0.5086 | Val Accuracy: 82.49%
#
# Epoch: 81
# 249 250 TrainLoss: 1.105 | TrainAcc: 58.976% (29488/50000)
# 99 100 ValLoss: 0.509 | Val Acc: 82.510% (8251/10000)
# Epoch 81/200 | Val Loss: 0.5091 | Val Accuracy: 82.51%
#
# Epoch: 82
# 249 250 TrainLoss: 1.114 | TrainAcc: 58.320% (29160/50000)
# 99 100 ValLoss: 0.527 | Val Acc: 81.940% (8194/10000)
# Epoch 82/200 | Val Loss: 0.5270 | Val Accuracy: 81.94%
#
# Epoch: 83
# 249 250 TrainLoss: 1.108 | TrainAcc: 58.712% (29356/50000)
# 99 100 ValLoss: 0.501 | Val Acc: 83.180% (8318/10000)
# Saving..
# Epoch 83/200 | Val Loss: 0.5011 | Val Accuracy: 83.18%
#
# Epoch: 84
# 249 250 TrainLoss: 1.108 | TrainAcc: 59.028% (29514/50000)
# 99 100 ValLoss: 0.503 | Val Acc: 82.900% (8290/10000)
# Epoch 84/200 | Val Loss: 0.5034 | Val Accuracy: 82.90%
#
# Epoch: 85
# 249 250 TrainLoss: 1.105 | TrainAcc: 59.018% (29509/50000)
# 99 100 ValLoss: 0.501 | Val Acc: 83.110% (8311/10000)
# Epoch 85/200 | Val Loss: 0.5014 | Val Accuracy: 83.11%
#
# Epoch: 86
# 249 250 TrainLoss: 1.099 | TrainAcc: 59.176% (29588/50000)
# 99 100 ValLoss: 0.497 | Val Acc: 83.080% (8308/10000)
# Epoch 86/200 | Val Loss: 0.4973 | Val Accuracy: 83.08%
#
# Epoch: 87
# 249 250 TrainLoss: 1.088 | TrainAcc: 59.544% (29772/50000)
# 99 100 ValLoss: 0.506 | Val Acc: 83.070% (8307/10000)
# Epoch 87/200 | Val Loss: 0.5062 | Val Accuracy: 83.07%
#
# Epoch: 88
# 249 250 TrainLoss: 1.090 | TrainAcc: 59.440% (29720/50000)
# 99 100 ValLoss: 0.491 | Val Acc: 83.350% (8335/10000)
# Saving..
# Epoch 88/200 | Val Loss: 0.4912 | Val Accuracy: 83.35%
#
# Epoch: 89
# 249 250 TrainLoss: 1.084 | TrainAcc: 59.868% (29934/50000)
# 99 100 ValLoss: 0.479 | Val Acc: 83.660% (8366/10000)
# Saving..
# Epoch 89/200 | Val Loss: 0.4791 | Val Accuracy: 83.66%
#
# Epoch: 90
# 249 250 TrainLoss: 1.082 | TrainAcc: 60.084% (30042/50000)
# 99 100 ValLoss: 0.491 | Val Acc: 83.150% (8315/10000)
# Epoch 90/200 | Val Loss: 0.4912 | Val Accuracy: 83.15%
#
# Epoch: 91
# 249 250 TrainLoss: 1.080 | TrainAcc: 60.000% (30000/50000)
# 99 100 ValLoss: 0.476 | Val Acc: 83.810% (8381/10000)
# Saving..
# Epoch 91/200 | Val Loss: 0.4761 | Val Accuracy: 83.81%
#
# Epoch: 92
# 249 250 TrainLoss: 1.081 | TrainAcc: 59.836% (29918/50000)
# 99 100 ValLoss: 0.477 | Val Acc: 83.210% (8321/10000)
# Epoch 92/200 | Val Loss: 0.4773 | Val Accuracy: 83.21%
#
# Epoch: 93
# 249 250 TrainLoss: 1.074 | TrainAcc: 60.000% (30000/50000)
# 99 100 ValLoss: 0.470 | Val Acc: 83.840% (8384/10000)
# Saving..
# Epoch 93/200 | Val Loss: 0.4698 | Val Accuracy: 83.84%
#
# Epoch: 94
# 249 250 TrainLoss: 1.064 | TrainAcc: 60.392% (30196/50000)
# 99 100 ValLoss: 0.471 | Val Acc: 84.120% (8412/10000)
# Saving..
# Epoch 94/200 | Val Loss: 0.4714 | Val Accuracy: 84.12%
#
# Epoch: 95
# 249 250 TrainLoss: 1.067 | TrainAcc: 60.278% (30139/50000)
# 99 100 ValLoss: 0.457 | Val Acc: 84.490% (8449/10000)
# Saving..
# Epoch 95/200 | Val Loss: 0.4572 | Val Accuracy: 84.49%
#
# Epoch: 96
# 249 250 TrainLoss: 1.063 | TrainAcc: 60.348% (30174/50000)
# 99 100 ValLoss: 0.482 | Val Acc: 83.290% (8329/10000)
# Epoch 96/200 | Val Loss: 0.4822 | Val Accuracy: 83.29%
#
# Epoch: 97
# 249 250 TrainLoss: 1.065 | TrainAcc: 60.128% (30064/50000)
# 99 100 ValLoss: 0.463 | Val Acc: 84.570% (8457/10000)
# Saving..
# Epoch 97/200 | Val Loss: 0.4634 | Val Accuracy: 84.57%
#
# Epoch: 98
# 249 250 TrainLoss: 1.052 | TrainAcc: 60.824% (30412/50000)
# 99 100 ValLoss: 0.467 | Val Acc: 84.310% (8431/10000)
# Epoch 98/200 | Val Loss: 0.4670 | Val Accuracy: 84.31%
#
# Epoch: 99
# 249 250 TrainLoss: 1.060 | TrainAcc: 60.656% (30328/50000)
# 99 100 ValLoss: 0.460 | Val Acc: 84.440% (8444/10000)
# Epoch 99/200 | Val Loss: 0.4598 | Val Accuracy: 84.44%
#
# Epoch: 100
# 249 250 TrainLoss: 1.055 | TrainAcc: 60.690% (30345/50000)
# 99 100 ValLoss: 0.457 | Val Acc: 84.440% (8444/10000)
# Epoch 100/200 | Val Loss: 0.4565 | Val Accuracy: 84.44%
#
# Epoch: 101
# 249 250 TrainLoss: 1.050 | TrainAcc: 60.980% (30490/50000)
# 99 100 ValLoss: 0.472 | Val Acc: 84.040% (8404/10000)
# Epoch 101/200 | Val Loss: 0.4725 | Val Accuracy: 84.04%
#
# Epoch: 102
# 249 250 TrainLoss: 1.047 | TrainAcc: 60.966% (30483/50000)
# 99 100 ValLoss: 0.453 | Val Acc: 84.960% (8496/10000)
# Saving..
# Epoch 102/200 | Val Loss: 0.4526 | Val Accuracy: 84.96%
#
# Epoch: 103
# 249 250 TrainLoss: 1.046 | TrainAcc: 61.022% (30511/50000)
# 99 100 ValLoss: 0.471 | Val Acc: 83.940% (8394/10000)
# Epoch 103/200 | Val Loss: 0.4712 | Val Accuracy: 83.94%
#
# Epoch: 104
# 249 250 TrainLoss: 1.048 | TrainAcc: 60.874% (30437/50000)
# 99 100 ValLoss: 0.450 | Val Acc: 84.680% (8468/10000)
# Epoch 104/200 | Val Loss: 0.4500 | Val Accuracy: 84.68%
#
# Epoch: 105
# 249 250 TrainLoss: 1.041 | TrainAcc: 61.274% (30637/50000)
# 99 100 ValLoss: 0.453 | Val Acc: 84.630% (8463/10000)
# Epoch 105/200 | Val Loss: 0.4528 | Val Accuracy: 84.63%
#
# Epoch: 106
# 249 250 TrainLoss: 1.035 | TrainAcc: 61.502% (30751/50000)
# 99 100 ValLoss: 0.456 | Val Acc: 84.610% (8461/10000)
# Epoch 106/200 | Val Loss: 0.4565 | Val Accuracy: 84.61%
#
# Epoch: 107
# 249 250 TrainLoss: 1.035 | TrainAcc: 61.588% (30794/50000)
# 99 100 ValLoss: 0.440 | Val Acc: 85.210% (8521/10000)
# Saving..
# Epoch 107/200 | Val Loss: 0.4402 | Val Accuracy: 85.21%
#
# Epoch: 108
# 249 250 TrainLoss: 1.032 | TrainAcc: 61.430% (30715/50000)
# 99 100 ValLoss: 0.458 | Val Acc: 84.850% (8485/10000)
# Epoch 108/200 | Val Loss: 0.4578 | Val Accuracy: 84.85%
#
# Epoch: 109
# 249 250 TrainLoss: 1.036 | TrainAcc: 61.172% (30586/50000)
# 99 100 ValLoss: 0.442 | Val Acc: 84.710% (8471/10000)
# Epoch 109/200 | Val Loss: 0.4424 | Val Accuracy: 84.71%
#
# Epoch: 110
# 249 250 TrainLoss: 1.022 | TrainAcc: 61.868% (30934/50000)
# 99 100 ValLoss: 0.436 | Val Acc: 85.120% (8512/10000)
# Epoch 110/200 | Val Loss: 0.4356 | Val Accuracy: 85.12%
#
# Epoch: 111
# 249 250 TrainLoss: 1.021 | TrainAcc: 61.844% (30922/50000)
# 99 100 ValLoss: 0.439 | Val Acc: 84.970% (8497/10000)
# Epoch 111/200 | Val Loss: 0.4389 | Val Accuracy: 84.97%
#
# Epoch: 112
# 249 250 TrainLoss: 1.022 | TrainAcc: 61.888% (30944/50000)
# 99 100 ValLoss: 0.444 | Val Acc: 85.110% (8511/10000)
# Epoch 112/200 | Val Loss: 0.4441 | Val Accuracy: 85.11%
#
# Epoch: 113
# 249 250 TrainLoss: 1.024 | TrainAcc: 61.590% (30795/50000)
# 99 100 ValLoss: 0.436 | Val Acc: 85.220% (8522/10000)
# Saving..
# Epoch 113/200 | Val Loss: 0.4362 | Val Accuracy: 85.22%
#
# Epoch: 114
# 249 250 TrainLoss: 1.007 | TrainAcc: 62.486% (31243/50000)
# 99 100 ValLoss: 0.421 | Val Acc: 85.530% (8553/10000)
# Saving..
# Epoch 114/200 | Val Loss: 0.4213 | Val Accuracy: 85.53%
#
# Epoch: 115
# 249 250 TrainLoss: 1.011 | TrainAcc: 62.392% (31196/50000)
# 99 100 ValLoss: 0.430 | Val Acc: 85.200% (8520/10000)
# Epoch 115/200 | Val Loss: 0.4304 | Val Accuracy: 85.20%
#
# Epoch: 116
# 249 250 TrainLoss: 1.007 | TrainAcc: 62.416% (31208/50000)
# 99 100 ValLoss: 0.424 | Val Acc: 85.690% (8569/10000)
# Saving..
# Epoch 116/200 | Val Loss: 0.4244 | Val Accuracy: 85.69%
#
# Epoch: 117
# 249 250 TrainLoss: 1.007 | TrainAcc: 62.352% (31176/50000)
# 99 100 ValLoss: 0.424 | Val Acc: 85.630% (8563/10000)
# Epoch 117/200 | Val Loss: 0.4242 | Val Accuracy: 85.63%
#
# Epoch: 118
# 249 250 TrainLoss: 1.001 | TrainAcc: 62.552% (31276/50000)
# 99 100 ValLoss: 0.435 | Val Acc: 85.250% (8525/10000)
# Epoch 118/200 | Val Loss: 0.4352 | Val Accuracy: 85.25%
#
# Epoch: 119
# 249 250 TrainLoss: 1.003 | TrainAcc: 62.530% (31265/50000)
# 99 100 ValLoss: 0.428 | Val Acc: 85.580% (8558/10000)
# Epoch 119/200 | Val Loss: 0.4276 | Val Accuracy: 85.58%
#
# Epoch: 120
# 249 250 TrainLoss: 1.003 | TrainAcc: 62.386% (31193/50000)
# 99 100 ValLoss: 0.425 | Val Acc: 85.820% (8582/10000)
# Saving..
# Epoch 120/200 | Val Loss: 0.4246 | Val Accuracy: 85.82%
#
# Epoch: 121
# 249 250 TrainLoss: 1.004 | TrainAcc: 62.456% (31228/50000)
# 99 100 ValLoss: 0.420 | Val Acc: 86.010% (8601/10000)
# Saving..
# Epoch 121/200 | Val Loss: 0.4197 | Val Accuracy: 86.01%
#
# Epoch: 122
# 249 250 TrainLoss: 0.997 | TrainAcc: 62.596% (31298/50000)
# 99 100 ValLoss: 0.426 | Val Acc: 85.860% (8586/10000)
# Epoch 122/200 | Val Loss: 0.4263 | Val Accuracy: 85.86%
#
# Epoch: 123
# 249 250 TrainLoss: 0.995 | TrainAcc: 62.808% (31404/50000)
# 99 100 ValLoss: 0.426 | Val Acc: 85.970% (8597/10000)
# Epoch 123/200 | Val Loss: 0.4255 | Val Accuracy: 85.97%
#
# Epoch: 124
# 249 250 TrainLoss: 0.990 | TrainAcc: 62.842% (31421/50000)
# 99 100 ValLoss: 0.432 | Val Acc: 85.690% (8569/10000)
# Epoch 124/200 | Val Loss: 0.4322 | Val Accuracy: 85.69%
#
# Epoch: 125
# 249 250 TrainLoss: 0.988 | TrainAcc: 63.020% (31510/50000)
# 99 100 ValLoss: 0.419 | Val Acc: 85.870% (8587/10000)
# Epoch 125/200 | Val Loss: 0.4195 | Val Accuracy: 85.87%
#
# Epoch: 126
# 249 250 TrainLoss: 0.992 | TrainAcc: 62.996% (31498/50000)
# 99 100 ValLoss: 0.421 | Val Acc: 86.000% (8600/10000)
# Epoch 126/200 | Val Loss: 0.4206 | Val Accuracy: 86.00%
#
# Epoch: 127
# 249 250 TrainLoss: 0.993 | TrainAcc: 62.910% (31455/50000)
# 99 100 ValLoss: 0.420 | Val Acc: 86.010% (8601/10000)
# Epoch 127/200 | Val Loss: 0.4198 | Val Accuracy: 86.01%
#
# Epoch: 128
# 249 250 TrainLoss: 0.991 | TrainAcc: 62.830% (31415/50000)
# 99 100 ValLoss: 0.417 | Val Acc: 86.050% (8605/10000)
# Saving..
# Epoch 128/200 | Val Loss: 0.4175 | Val Accuracy: 86.05%
#
# Epoch: 129
# 249 250 TrainLoss: 0.988 | TrainAcc: 63.018% (31509/50000)
# 99 100 ValLoss: 0.419 | Val Acc: 86.270% (8627/10000)
# Saving..
# Epoch 129/200 | Val Loss: 0.4193 | Val Accuracy: 86.27%
#
# Epoch: 130
# 249 250 TrainLoss: 0.979 | TrainAcc: 63.352% (31676/50000)
# 99 100 ValLoss: 0.420 | Val Acc: 85.760% (8576/10000)
# Epoch 130/200 | Val Loss: 0.4201 | Val Accuracy: 85.76%
#
# Epoch: 131
# 249 250 TrainLoss: 0.977 | TrainAcc: 63.572% (31786/50000)
# 99 100 ValLoss: 0.424 | Val Acc: 85.960% (8596/10000)
# Epoch 131/200 | Val Loss: 0.4241 | Val Accuracy: 85.96%
#
# Epoch: 132
# 249 250 TrainLoss: 0.966 | TrainAcc: 64.028% (32014/50000)
# 99 100 ValLoss: 0.415 | Val Acc: 86.170% (8617/10000)
# Epoch 132/200 | Val Loss: 0.4152 | Val Accuracy: 86.17%
#
# Epoch: 133
# 249 250 TrainLoss: 0.972 | TrainAcc: 63.432% (31716/50000)
# 99 100 ValLoss: 0.411 | Val Acc: 86.240% (8624/10000)
# Epoch 133/200 | Val Loss: 0.4110 | Val Accuracy: 86.24%
#
# Epoch: 134
# 249 250 TrainLoss: 0.974 | TrainAcc: 63.484% (31742/50000)
# 99 100 ValLoss: 0.416 | Val Acc: 86.230% (8623/10000)
# Epoch 134/200 | Val Loss: 0.4157 | Val Accuracy: 86.23%
#
# Epoch: 135
# 249 250 TrainLoss: 0.977 | TrainAcc: 63.286% (31643/50000)
# 99 100 ValLoss: 0.407 | Val Acc: 86.540% (8654/10000)
# Saving..
# Epoch 135/200 | Val Loss: 0.4070 | Val Accuracy: 86.54%
#
# Epoch: 136
# 249 250 TrainLoss: 0.969 | TrainAcc: 63.662% (31831/50000)
# 99 100 ValLoss: 0.409 | Val Acc: 86.610% (8661/10000)
# Saving..
# Epoch 136/200 | Val Loss: 0.4089 | Val Accuracy: 86.61%
#
# Epoch: 137
# 249 250 TrainLoss: 0.962 | TrainAcc: 63.834% (31917/50000)
# 99 100 ValLoss: 0.409 | Val Acc: 86.280% (8628/10000)
# Epoch 137/200 | Val Loss: 0.4093 | Val Accuracy: 86.28%
#
# Epoch: 138
# 249 250 TrainLoss: 0.966 | TrainAcc: 63.568% (31784/50000)
# 99 100 ValLoss: 0.400 | Val Acc: 86.710% (8671/10000)
# Saving..
# Epoch 138/200 | Val Loss: 0.4000 | Val Accuracy: 86.71%
#
# Epoch: 139
# 249 250 TrainLoss: 0.958 | TrainAcc: 64.026% (32013/50000)
# 99 100 ValLoss: 0.409 | Val Acc: 86.320% (8632/10000)
# Epoch 139/200 | Val Loss: 0.4091 | Val Accuracy: 86.32%
#
# Epoch: 140
# 249 250 TrainLoss: 0.960 | TrainAcc: 64.126% (32063/50000)
# 99 100 ValLoss: 0.406 | Val Acc: 86.290% (8629/10000)
# Epoch 140/200 | Val Loss: 0.4062 | Val Accuracy: 86.29%
#
# Epoch: 141
# 249 250 TrainLoss: 0.960 | TrainAcc: 64.072% (32036/50000)
# 99 100 ValLoss: 0.406 | Val Acc: 86.630% (8663/10000)
# Epoch 141/200 | Val Loss: 0.4063 | Val Accuracy: 86.63%
#
# Epoch: 142
# 249 250 TrainLoss: 0.958 | TrainAcc: 64.004% (32002/50000)
# 99 100 ValLoss: 0.407 | Val Acc: 86.670% (8667/10000)
# Epoch 142/200 | Val Loss: 0.4071 | Val Accuracy: 86.67%
#
# Epoch: 143
# 249 250 TrainLoss: 0.958 | TrainAcc: 63.910% (31955/50000)
# 99 100 ValLoss: 0.404 | Val Acc: 86.630% (8663/10000)
# Epoch 143/200 | Val Loss: 0.4043 | Val Accuracy: 86.63%
#
# Epoch: 144
# 249 250 TrainLoss: 0.953 | TrainAcc: 64.262% (32131/50000)
# 99 100 ValLoss: 0.400 | Val Acc: 86.760% (8676/10000)
# Saving..
# Epoch 144/200 | Val Loss: 0.4000 | Val Accuracy: 86.76%
#
# Epoch: 145
# 249 250 TrainLoss: 0.951 | TrainAcc: 64.176% (32088/50000)
# 99 100 ValLoss: 0.403 | Val Acc: 86.660% (8666/10000)
# Epoch 145/200 | Val Loss: 0.4034 | Val Accuracy: 86.66%
#
# Epoch: 146
# 249 250 TrainLoss: 0.940 | TrainAcc: 64.666% (32333/50000)
# 99 100 ValLoss: 0.399 | Val Acc: 86.860% (8686/10000)
# Saving..
# Epoch 146/200 | Val Loss: 0.3985 | Val Accuracy: 86.86%
#
# Epoch: 147
# 249 250 TrainLoss: 0.950 | TrainAcc: 64.328% (32164/50000)
# 99 100 ValLoss: 0.416 | Val Acc: 86.310% (8631/10000)
# Epoch 147/200 | Val Loss: 0.4156 | Val Accuracy: 86.31%
#
# Epoch: 148
# 249 250 TrainLoss: 0.949 | TrainAcc: 64.460% (32230/50000)
# 99 100 ValLoss: 0.399 | Val Acc: 86.620% (8662/10000)
# Epoch 148/200 | Val Loss: 0.3990 | Val Accuracy: 86.62%
#
# Epoch: 149
# 249 250 TrainLoss: 0.946 | TrainAcc: 64.488% (32244/50000)
# 99 100 ValLoss: 0.403 | Val Acc: 86.710% (8671/10000)
# Epoch 149/200 | Val Loss: 0.4027 | Val Accuracy: 86.71%
#
# Epoch: 150
# 249 250 TrainLoss: 0.944 | TrainAcc: 64.498% (32249/50000)
# 99 100 ValLoss: 0.410 | Val Acc: 86.680% (8668/10000)
# Epoch 150/200 | Val Loss: 0.4102 | Val Accuracy: 86.68%
#
# Epoch: 151
# 249 250 TrainLoss: 0.943 | TrainAcc: 64.548% (32274/50000)
# 99 100 ValLoss: 0.400 | Val Acc: 86.940% (8694/10000)
# Saving..
# Epoch 151/200 | Val Loss: 0.3997 | Val Accuracy: 86.94%
#
# Epoch: 152
# 249 250 TrainLoss: 0.939 | TrainAcc: 64.918% (32459/50000)
# 99 100 ValLoss: 0.399 | Val Acc: 87.050% (8705/10000)
# Saving..
# Epoch 152/200 | Val Loss: 0.3988 | Val Accuracy: 87.05%
#
# Epoch: 153
# 249 250 TrainLoss: 0.953 | TrainAcc: 64.362% (32181/50000)
# 99 100 ValLoss: 0.404 | Val Acc: 86.700% (8670/10000)
# Epoch 153/200 | Val Loss: 0.4039 | Val Accuracy: 86.70%
#
# Epoch: 154
# 249 250 TrainLoss: 0.937 | TrainAcc: 64.800% (32400/50000)
# 99 100 ValLoss: 0.399 | Val Acc: 86.870% (8687/10000)
# Epoch 154/200 | Val Loss: 0.3985 | Val Accuracy: 86.87%
#
# Epoch: 155
# 249 250 TrainLoss: 0.936 | TrainAcc: 64.730% (32365/50000)
# 99 100 ValLoss: 0.401 | Val Acc: 86.690% (8669/10000)
# Epoch 155/200 | Val Loss: 0.4013 | Val Accuracy: 86.69%
#
# Epoch: 156
# 249 250 TrainLoss: 0.944 | TrainAcc: 64.458% (32229/50000)
# 99 100 ValLoss: 0.406 | Val Acc: 87.020% (8702/10000)
# Epoch 156/200 | Val Loss: 0.4057 | Val Accuracy: 87.02%
#
# Epoch: 157
# 249 250 TrainLoss: 0.938 | TrainAcc: 64.838% (32419/50000)
# 99 100 ValLoss: 0.392 | Val Acc: 87.040% (8704/10000)
# Epoch 157/200 | Val Loss: 0.3923 | Val Accuracy: 87.04%
#
# Epoch: 158
# 249 250 TrainLoss: 0.940 | TrainAcc: 64.780% (32390/50000)
# 99 100 ValLoss: 0.395 | Val Acc: 86.960% (8696/10000)
# Epoch 158/200 | Val Loss: 0.3951 | Val Accuracy: 86.96%
#
# Epoch: 159
# 249 250 TrainLoss: 0.931 | TrainAcc: 65.058% (32529/50000)
# 99 100 ValLoss: 0.406 | Val Acc: 86.900% (8690/10000)
# Epoch 159/200 | Val Loss: 0.4065 | Val Accuracy: 86.90%
#
# Epoch: 160
# 249 250 TrainLoss: 0.938 | TrainAcc: 64.726% (32363/50000)
# 99 100 ValLoss: 0.395 | Val Acc: 87.020% (8702/10000)
# Epoch 160/200 | Val Loss: 0.3947 | Val Accuracy: 87.02%
#
# Epoch: 161
# 249 250 TrainLoss: 0.928 | TrainAcc: 65.332% (32666/50000)
# 99 100 ValLoss: 0.399 | Val Acc: 86.850% (8685/10000)
# Epoch 161/200 | Val Loss: 0.3988 | Val Accuracy: 86.85%
#
# Epoch: 162
# 249 250 TrainLoss: 0.940 | TrainAcc: 64.552% (32276/50000)
# 99 100 ValLoss: 0.399 | Val Acc: 86.820% (8682/10000)
# Epoch 162/200 | Val Loss: 0.3993 | Val Accuracy: 86.82%
#
# Epoch: 163
# 249 250 TrainLoss: 0.929 | TrainAcc: 65.178% (32589/50000)
# 99 100 ValLoss: 0.398 | Val Acc: 87.160% (8716/10000)
# Saving..
# Epoch 163/200 | Val Loss: 0.3981 | Val Accuracy: 87.16%
#
# Epoch: 164
# 249 250 TrainLoss: 0.928 | TrainAcc: 64.934% (32467/50000)
# 99 100 ValLoss: 0.394 | Val Acc: 87.150% (8715/10000)
# Epoch 164/200 | Val Loss: 0.3942 | Val Accuracy: 87.15%
#
# Epoch: 165
# 249 250 TrainLoss: 0.923 | TrainAcc: 65.516% (32758/50000)
# 99 100 ValLoss: 0.393 | Val Acc: 87.010% (8701/10000)
# Epoch 165/200 | Val Loss: 0.3927 | Val Accuracy: 87.01%
#
# Epoch: 166
# 249 250 TrainLoss: 0.928 | TrainAcc: 65.138% (32569/50000)
# 99 100 ValLoss: 0.396 | Val Acc: 87.100% (8710/10000)
# Epoch 166/200 | Val Loss: 0.3960 | Val Accuracy: 87.10%
#
# Epoch: 167
# 249 250 TrainLoss: 0.929 | TrainAcc: 64.970% (32485/50000)
# 99 100 ValLoss: 0.387 | Val Acc: 87.260% (8726/10000)
# Saving..
# Epoch 167/200 | Val Loss: 0.3874 | Val Accuracy: 87.26%
#
# Epoch: 168
# 249 250 TrainLoss: 0.930 | TrainAcc: 65.070% (32535/50000)
# 99 100 ValLoss: 0.394 | Val Acc: 87.180% (8718/10000)
# Epoch 168/200 | Val Loss: 0.3945 | Val Accuracy: 87.18%
#
# Epoch: 169
# 249 250 TrainLoss: 0.925 | TrainAcc: 65.174% (32587/50000)
# 99 100 ValLoss: 0.389 | Val Acc: 87.380% (8738/10000)
# Saving..
# Epoch 169/200 | Val Loss: 0.3893 | Val Accuracy: 87.38%
#
# Epoch: 170
# 249 250 TrainLoss: 0.921 | TrainAcc: 65.336% (32668/50000)
# 99 100 ValLoss: 0.395 | Val Acc: 87.300% (8730/10000)
# Epoch 170/200 | Val Loss: 0.3948 | Val Accuracy: 87.30%
#
# Epoch: 171
# 249 250 TrainLoss: 0.927 | TrainAcc: 65.234% (32617/50000)
# 99 100 ValLoss: 0.398 | Val Acc: 86.990% (8699/10000)
# Epoch 171/200 | Val Loss: 0.3978 | Val Accuracy: 86.99%
#
# Epoch: 172
# 249 250 TrainLoss: 0.919 | TrainAcc: 65.332% (32666/50000)
# 99 100 ValLoss: 0.389 | Val Acc: 87.330% (8733/10000)
# Epoch 172/200 | Val Loss: 0.3891 | Val Accuracy: 87.33%
#
# Epoch: 173
# 249 250 TrainLoss: 0.923 | TrainAcc: 65.312% (32656/50000)
# 99 100 ValLoss: 0.391 | Val Acc: 87.420% (8742/10000)
# Saving..
# Epoch 173/200 | Val Loss: 0.3909 | Val Accuracy: 87.42%
#
# Epoch: 174
# 249 250 TrainLoss: 0.925 | TrainAcc: 65.260% (32630/50000)
# 99 100 ValLoss: 0.391 | Val Acc: 87.200% (8720/10000)
# Epoch 174/200 | Val Loss: 0.3909 | Val Accuracy: 87.20%
#
# Epoch: 175
# 249 250 TrainLoss: 0.925 | TrainAcc: 65.314% (32657/50000)
# 99 100 ValLoss: 0.389 | Val Acc: 87.240% (8724/10000)
# Epoch 175/200 | Val Loss: 0.3887 | Val Accuracy: 87.24%
#
# Epoch: 176
# 249 250 TrainLoss: 0.922 | TrainAcc: 65.366% (32683/50000)
# 99 100 ValLoss: 0.392 | Val Acc: 87.180% (8718/10000)
# Epoch 176/200 | Val Loss: 0.3924 | Val Accuracy: 87.18%
#
# Epoch: 177
# 249 250 TrainLoss: 0.922 | TrainAcc: 65.374% (32687/50000)
# 99 100 ValLoss: 0.390 | Val Acc: 87.460% (8746/10000)
# Saving..
# Epoch 177/200 | Val Loss: 0.3898 | Val Accuracy: 87.46%
#
# Epoch: 178
# 249 250 TrainLoss: 0.915 | TrainAcc: 65.456% (32728/50000)
# 99 100 ValLoss: 0.390 | Val Acc: 87.240% (8724/10000)
# Epoch 178/200 | Val Loss: 0.3897 | Val Accuracy: 87.24%
#
# Epoch: 179
# 249 250 TrainLoss: 0.923 | TrainAcc: 65.234% (32617/50000)
# 99 100 ValLoss: 0.391 | Val Acc: 87.330% (8733/10000)
# Epoch 179/200 | Val Loss: 0.3914 | Val Accuracy: 87.33%
#
# Epoch: 180
# 249 250 TrainLoss: 0.909 | TrainAcc: 65.908% (32954/50000)
# 99 100 ValLoss: 0.389 | Val Acc: 87.340% (8734/10000)
# Epoch 180/200 | Val Loss: 0.3888 | Val Accuracy: 87.34%
#
# Epoch: 181
# 249 250 TrainLoss: 0.907 | TrainAcc: 65.948% (32974/50000)
# 99 100 ValLoss: 0.391 | Val Acc: 87.230% (8723/10000)
# Epoch 181/200 | Val Loss: 0.3913 | Val Accuracy: 87.23%
#
# Epoch: 182
# 249 250 TrainLoss: 0.919 | TrainAcc: 65.088% (32544/50000)
# 99 100 ValLoss: 0.390 | Val Acc: 87.140% (8714/10000)
# Epoch 182/200 | Val Loss: 0.3900 | Val Accuracy: 87.14%
#
# Epoch: 183
# 249 250 TrainLoss: 0.921 | TrainAcc: 65.354% (32677/50000)
# 99 100 ValLoss: 0.393 | Val Acc: 87.260% (8726/10000)
# Epoch 183/200 | Val Loss: 0.3929 | Val Accuracy: 87.26%
#
# Epoch: 184
# 249 250 TrainLoss: 0.916 | TrainAcc: 65.624% (32812/50000)
# 99 100 ValLoss: 0.389 | Val Acc: 87.300% (8730/10000)
# Epoch 184/200 | Val Loss: 0.3894 | Val Accuracy: 87.30%
#
# Epoch: 185
# 249 250 TrainLoss: 0.920 | TrainAcc: 65.278% (32639/50000)
# 99 100 ValLoss: 0.391 | Val Acc: 87.320% (8732/10000)
# Epoch 185/200 | Val Loss: 0.3906 | Val Accuracy: 87.32%
#
# Epoch: 186
# 249 250 TrainLoss: 0.915 | TrainAcc: 65.646% (32823/50000)
# 99 100 ValLoss: 0.391 | Val Acc: 87.380% (8738/10000)
# Epoch 186/200 | Val Loss: 0.3910 | Val Accuracy: 87.38%
#
# Epoch: 187
# 249 250 TrainLoss: 0.920 | TrainAcc: 65.506% (32753/50000)
# 99 100 ValLoss: 0.389 | Val Acc: 87.260% (8726/10000)
# Epoch 187/200 | Val Loss: 0.3895 | Val Accuracy: 87.26%
#
# Epoch: 188
# 249 250 TrainLoss: 0.915 | TrainAcc: 65.626% (32813/50000)
# 99 100 ValLoss: 0.390 | Val Acc: 87.250% (8725/10000)
# Epoch 188/200 | Val Loss: 0.3899 | Val Accuracy: 87.25%
#
# Epoch: 189
# 249 250 TrainLoss: 0.922 | TrainAcc: 65.304% (32652/50000)
# 99 100 ValLoss: 0.389 | Val Acc: 87.220% (8722/10000)
# Epoch 189/200 | Val Loss: 0.3891 | Val Accuracy: 87.22%
#
# Epoch: 190
# 249 250 TrainLoss: 0.918 | TrainAcc: 65.340% (32670/50000)
# 99 100 ValLoss: 0.389 | Val Acc: 87.360% (8736/10000)
# Epoch 190/200 | Val Loss: 0.3889 | Val Accuracy: 87.36%
#
# Epoch: 191
# 249 250 TrainLoss: 0.913 | TrainAcc: 65.602% (32801/50000)
# 99 100 ValLoss: 0.390 | Val Acc: 87.360% (8736/10000)
# Epoch 191/200 | Val Loss: 0.3899 | Val Accuracy: 87.36%
#
# Epoch: 192
# 249 250 TrainLoss: 0.909 | TrainAcc: 65.634% (32817/50000)
# 99 100 ValLoss: 0.389 | Val Acc: 87.310% (8731/10000)
# Epoch 192/200 | Val Loss: 0.3892 | Val Accuracy: 87.31%
#
# Epoch: 193
# 249 250 TrainLoss: 0.910 | TrainAcc: 65.710% (32855/50000)
# 99 100 ValLoss: 0.390 | Val Acc: 87.250% (8725/10000)
# Epoch 193/200 | Val Loss: 0.3896 | Val Accuracy: 87.25%
#
# Epoch: 194
# 249 250 TrainLoss: 0.913 | TrainAcc: 65.470% (32735/50000)
# 99 100 ValLoss: 0.390 | Val Acc: 87.280% (8728/10000)
# Epoch 194/200 | Val Loss: 0.3903 | Val Accuracy: 87.28%
#
# Epoch: 195
# 249 250 TrainLoss: 0.910 | TrainAcc: 65.652% (32826/50000)
# 99 100 ValLoss: 0.390 | Val Acc: 87.270% (8727/10000)
# Epoch 195/200 | Val Loss: 0.3903 | Val Accuracy: 87.27%
#
# Epoch: 196
# 249 250 TrainLoss: 0.916 | TrainAcc: 65.480% (32740/50000)
# 99 100 ValLoss: 0.390 | Val Acc: 87.280% (8728/10000)
# Epoch 196/200 | Val Loss: 0.3905 | Val Accuracy: 87.28%
#
# Epoch: 197
# 249 250 TrainLoss: 0.913 | TrainAcc: 65.470% (32735/50000)
# 99 100 ValLoss: 0.390 | Val Acc: 87.240% (8724/10000)
# Epoch 197/200 | Val Loss: 0.3902 | Val Accuracy: 87.24%
#
# Epoch: 198
# 249 250 TrainLoss: 0.917 | TrainAcc: 65.460% (32730/50000)
# 99 100 ValLoss: 0.390 | Val Acc: 87.250% (8725/10000)
# Epoch 198/200 | Val Loss: 0.3900 | Val Accuracy: 87.25%
#
# Epoch: 199
# 249 250 TrainLoss: 0.912 | TrainAcc: 65.570% (32785/50000)
# 99 100 ValLoss: 0.390 | Val Acc: 87.280% (8728/10000)
# Epoch 199/200 | Val Loss: 0.3899 | Val Accuracy: 87.28%
#
# Epoch: 200
# 249 250 TrainLoss: 0.915 | TrainAcc: 65.458% (32729/50000)
# 99 100 ValLoss: 0.390 | Val Acc: 87.250% (8725/10000)
# Epoch 200/200 | Val Loss: 0.3899 | Val Accuracy: 87.25%

# %% [markdown]
# ### Save the training and Testing metrics locally

# %%
import pandas as pd

# Create a DataFrame from the lists
df_metrics = pd.DataFrame({
    'Epoch': list(range(1, len(list_acc) + 1)),
    'Train_Loss': list_train_loss,
    'Train_Acc': list_train_acc,
    'Test_Loss': list_loss,
    'Test_Acc': list_acc
})

# Save to CSV
df_metrics.to_csv("swin_cifar10_2211_adam_metrics.csv", index=False)

print("Metrics saved to 'swin_cifar10_metrics.csv'")
# Out:
# Metrics saved to 'swin_cifar10_metrics.csv'

# %% [markdown]
# ### Load Best Checkpoint and Visualize Predictions on Sample Test Images

# %%
# Load best model from checkpoint
from swin_transformer_pytorch import swin_t

net = swin_t(window_size=int(args.patch),
             num_classes=int(args.dataset_classes),
             downscaling_factors=(2, 2, 2, 1)).to(device)

# Instantiate the model using parsed args
checkpoint = torch.load('./checkpoint/swin-4-ckpt.t7', map_location=device)  # use correct patch size
net.load_state_dict(checkpoint['model'])
net.eval()

classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# Show 5 test samples with predictions
import matplotlib.pyplot as plt
dataiter = iter(testloader)
images, labels = next(dataiter)

images, labels = images[:5], labels[:5]
outputs = net(images.cuda())
_, preds = torch.max(outputs, 1)

# Unnormalize and display
mean = torch.tensor((0.4914, 0.4822, 0.4465)).view(3,1,1)
std = torch.tensor((0.2023, 0.1994, 0.2010)).view(3,1,1)

fig, axes = plt.subplots(1, 5, figsize=(15,3))
for idx in range(5):
    img = images[idx].cpu() * std + mean
    img = img.permute(1,2,0).clamp(0,1).numpy()
    axes[idx].imshow(img)
    axes[idx].set_title(f"Pred: {classes[preds[idx]]}\nTrue: {classes[labels[idx]]}")
    axes[idx].axis('off')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_27548\308380026.py:9: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load('./checkpoint/swin-4-ckpt.t7', map_location=device)  # use correct patch size

# %% [markdown]
# ### Visualize Training and Validation Accuracy and Loss Over Epochs

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(list_acc) + 1)

# Accuracy Plot
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs, list_train_acc, label='Train Accuracy', marker='o')
plt.plot(epochs, list_acc, label='Validation Accuracy', marker='o')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Train vs Validation Accuracy')
plt.legend()

# Loss Plot
plt.subplot(1, 2, 2)
plt.plot(epochs, list_train_loss, label='Train Loss', marker='o')
plt.plot(epochs, list_loss, label='Validation Loss', marker='o')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Train vs Validation Loss')
plt.legend()

plt.tight_layout()
plt.show()
